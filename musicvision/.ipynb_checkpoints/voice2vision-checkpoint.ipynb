# %% [markdown]
# ### 将mp3转换成wav

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from pydub import AudioSegment
import wave


sound = AudioSegment.from_mp3("./music/mixiang.mp3")
sound.export("a",format="wav")

sound2 = AudioSegment.from_mp3("./music/qiyueshang.mp3")
sound2.export("b",format="wav")

sound2 = AudioSegment.from_mp3("./music/chongqinghun.mp3")
sound2.export("c",format="wav")
# Out:
# <open file 'c', mode 'wb+' at 0x7f72c2471420>

# %% [markdown]
# ### 读取.wav文件
# wave.open(file,mode)
#
# mode:
#
#   'rb' ,读取文件
#
#   'wb' ,写入文件

# %%
f = wave.open("./music/a",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)
waveData = np.fromstring(strData,dtype=np.int16)
waveData = waveData*1.0/(max(abs(waveData)))


time = np.arange(0,nframes)*(1.0 / framerate)
plt.plot(time,waveData)
plt.xlabel("Time(s)")
plt.ylabel("Amplitude")
plt.title("Single channel wavedata")
plt.grid('on')#标尺，on：有，off:无。
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-9cfc20eaf2be> in <module>()
#       8
#       9 time = np.arange(0,nframes)*(1.0 / framerate)
# ---> 10 plt.plot(time,waveData)
#      11 plt.xlabel("Time(s)")
#      12 plt.ylabel("Amplitude")
#
# /home/xdy/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# /home/xdy/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
# ...

# %%
-

# %%
#coding:utf-8
import wave
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from PIL import Image 
 
    
f = wave.open("./music/a",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)#读取音频，字符串格式
waveData = np.fromstring(strData,dtype=np.int16)#将字符串转化为int
waveData = waveData*1.0/(max(abs(waveData)))#wave幅值归一化
waveData = np.reshape(waveData,[nframes,nchannels]).T
f.close()
# plot the wave
plt.figure(2)
ax1=plt.subplot(211)#在图表2中创建子图1  
ax2=plt.subplot(212)#在图表2中创建子图2  

plt.sca(ax1)  
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel(u'觅香 - Time(s)')
pic = plt.set_cmap('hot')


plt.sca(ax2)  
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel(u'觅香 - Time(s)')
plt.set_cmap('gray')
plt.show()

import wave
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from PIL import Image 
 
    
f = wave.open("./music/b",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)#读取音频，字符串格式
waveData = np.fromstring(strData,dtype=np.int16)#将字符串转化为int
waveData = waveData*1.0/(max(abs(waveData)))#wave幅值归一化
waveData = np.reshape(waveData,[nframes,nchannels]).T
f.close()
# plot the wave
plt.figure(2)
ax1=plt.subplot(211)#在图表2中创建子图1  
ax2=plt.subplot(212)#在图表2中创建子图2  

plt.sca(ax1)  
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel(u'七月上 - Time(s)')
pic = plt.set_cmap('hot')


plt.sca(ax2)  
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel(u'七月上 - Time(s)')
plt.set_cmap('gray')
plt.show()

# %%
import wave
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from PIL import Image 
 
    
f = wave.open("./music/c",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)#读取音频，字符串格式
waveData = np.fromstring(strData,dtype=np.int16)#将字符串转化为int
waveData = waveData*1.0/(max(abs(waveData)))#wave幅值归一化
waveData = np.reshape(waveData,[nframes,nchannels]).T
f.close()
# plot the wave
plt.figure(2)
ax1=plt.subplot(211)#在图表2中创建子图1  
ax2=plt.subplot(212)#在图表2中创建子图2  

plt.sca(ax1)  
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel('Time(s)')
pic = plt.set_cmap('hot')


plt.sca(ax2)  
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel('Time(s)')
plt.set_cmap('gray')
plt.show()
# Out:
# /home/xdy/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:7221: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %%
import wave
import matplotlib.pyplot as plt
import numpy as np
import os

    
f = wave.open("./music/c",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)#读取音频，字符串格式
waveData = np.fromstring(strData,dtype=np.int16)#将字符串转化为int
waveData = waveData*1.0/(max(abs(waveData)))#wave幅值归一化
waveData = np.reshape(waveData,[nframes,nchannels])
f.close()
# plot the wave
time = np.arange(0,nframes)*(1.0 / framerate)
data =waveData[:,0]

print time
plt1 = plt.figure(1)
#plt.subplot(5,1,1)
plt.plot(time,waveData[:,0])
#plt.plot(time[0:2500],data[0:2500])
plt.xlabel("Time(s)")
plt.ylabel("Amplitude")
plt.title("mixiang wavedata")
plt.grid('on')#标尺，on：有，off:无。

plt.show()
# Out:
# [  0.00000000e+00   2.26757370e-05   4.53514739e-05 ...,   1.75359932e+02
#    1.75359955e+02   1.75359977e+02]

# %%
import wave
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from PIL import Image 
 
    
f = wave.open("./music/a",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)#读取音频，字符串格式
waveData = np.fromstring(strData,dtype=np.int16)#将字符串转化为int
waveData = waveData*1.0/(max(abs(waveData)))#wave幅值归一化
waveData = np.reshape(waveData,[nframes,nchannels]).T
f.close()
# plot the wave
plt.figure()
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel('Time(s)')
pic = plt.set_cmap('hot')

plt.show()

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from pydub import AudioSegment
import wave


sound = AudioSegment.from_mp3("./music/You Are Not Alone.mp3")
sound.export("f",format="wav")

import wave
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from PIL import Image 
 
    
f = wave.open("./music/f",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)#读取音频，字符串格式
waveData = np.fromstring(strData,dtype=np.int16)#将字符串转化为int
waveData = waveData*1.0/(max(abs(waveData)))#wave幅值归一化
waveData = np.reshape(waveData,[nframes,nchannels]).T
f.close()
# plot the wave
plt.figure()
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel('Time(s)')
pic = plt.set_cmap('hot')

plt.show()

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from pydub import AudioSegment
import wave


sound2 = AudioSegment.from_mp3("./music/zuowen.mp3")
sound2.export("zuowen",format="wav")

import wave
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from PIL import Image 
 
    
f = wave.open("./music/zuowen",'rb')
params = f.getparams()
nchannels, sampwidth, framerate, nframes = params[:4]
strData = f.readframes(nframes)#读取音频，字符串格式
waveData = np.fromstring(strData,dtype=np.int16)#将字符串转化为int
waveData = waveData*1.0/(max(abs(waveData)))#wave幅值归一化
waveData = np.reshape(waveData,[nframes,nchannels]).T
f.close()
# plot the wave
plt.figure()
plt.specgram(waveData[0],Fs = framerate, scale_by_freq = True, sides = 'default')
plt.ylabel('Frequency(Hz)')
plt.xlabel('Time(s)')
pic = plt.set_cmap('hot')

plt.show()
